# %%
import pandas as pd

# %%
data = pd.read_csv('ciliary_body_v26_cataract.csv', header=None)
data
# Out:
#              0         1
# 0     1.190867  0.195052
# 1     2.111249  0.199482
# 2     3.031631  0.203912
# 3     3.952013  0.208343
# 4     4.872396  0.212773
# ..         ...       ...
# 104  96.603831  0.936872
# 105  97.524213  0.940810
# 106  98.444596  0.944994
# 107  99.364978  0.948686
# 108   0.271924  0.190445
#
# [109 rows x 2 columns]

# %%
data.sort_values(by=0, inplace=True)

# %%
print(data)
# Out:
#              0         1
# 108   0.271924  0.190445
# 0     1.190867  0.195052
# 1     2.111249  0.199482
# 2     3.031631  0.203912
# 3     3.952013  0.208343
# ..         ...       ...
# 103  95.683449  0.932687
# 104  96.603831  0.936872
# 105  97.524213  0.940810
# 106  98.444596  0.944994
# 107  99.364978  0.948686
#
# [109 rows x 2 columns]
